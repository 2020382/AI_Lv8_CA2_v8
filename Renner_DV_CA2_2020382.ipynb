# %% [markdown]
# ### Artificial inteligence
#
#
# Lecturer: David McQuaid
#
# Student/ID: Renner Santana / 2020382
#
# Due date: 19/11/2023
#
# Submission Date: 19/11/2023

# %% [markdown]
# ### Introduction
#
# The provided graph represents the possible routes in a puzzle with the starting point "A" and the solution point "S", the point on this search is to obtain the differences between a graph and a tree and explain how the graph is an abstraction of the problem and the advantages of using this visualization as this graph, and find the shortest path to the solution or point 'S'. Starting pointing out the difference between a graph and a tree and the shortest path using dijkstra algorithm and a* algorithm.

# %% [markdown]
# ### Differences between a graph and a tree !
#
#
# Graph is a collection of two sets also known as nodes and edges that connect the two sets, graph can be direct and undirect, it just means that edges can have a specific direction or not.
#
# A directed graph can also have weighted edges, and is also known as a digraph, where each edge has a weight or cost associated with it. Graphs can be represented in various ways such as adjacency matrix or adjacency list. In a direct graph the edges/nodes are linked to one direction whereas undirected can have diferent paths not only one forward way like direct graph.
#
#
# A tree is a non-linear data structure that represents the hierarchy. A tree is a collection of nodes that are linked together to form a hierarchy and its elements are arranged in multiple levels. The figure below is an example of a hierachy tree.

# %% [markdown]
#         A
#        / \
#       B   C
#      / \
#     D   E

# %% [markdown]
# Basic comparisson between a graph and a tree:
#
# - A tree is a non-linear data structure, a graph is also a non-linear data structure.
# - A tree is a collection of edges and nodes, and its structure can be written like T = {N,E} and a graph is a collection of vertices and edges and having its structre written like T = {V, E}.
# - In the root node of a tree in tree data structure, there is a unique node known as a parent node. It is the topmost node in the data structure of a tree. In a graph theres no unique node.
# - In a loop formation of a tree it does not create any loop in graph it can be formed.
# - Tree data structure will always have directed edges all the edges can either be directed edges, undirected edges, or both.

# %% [markdown]
# ### How is the graph an abstraction of the problem?

# %% [markdown]
# - The graph is an abstraction of the problem in the sense that finding the shortest path in direction effective is essential, to solve this shortest path problem, often using Dijkstra algorithmn and a* algorith.Dijkstra and A* almost have the same performance when using it to solve town or regional scale maps, but A* is better when using it to solve a large scale map making it easy to find a stage in the puzzle.
#
#
# - It simplifies the puzzle by representing it as a set of nodes (points) or values connected by edges (routes). This abstraction captures the essential relationships and possible routes between the starting point "A" and the solution "S". Abstractions allow us to represent real-world problems in a more manageable and understandable way.
#
#
# - Dijkstra's algorithm is a simple and efficient way to find the shortest path from a root node to all other nodes in a graph. However, if we are only interested in the shortest path to a particular vertex, it may search much more of the graph than necessary.
#
#
# - A second and more interesting optimization is to take advantage of more knowledge of distances in the graph. Dijkstra's algorithm searches outward in distance order from the source node and finds the best route to every node in the graph. In general we don't want to know every best route.
#
#
# - With the starting point as the root and intermediate stages named by letters and its values as numbers, leading to the solution point or "S", it reflects a hierarchical relationship. This abstraction simplifies the puzzle's structure into a clear undestanding. The edges between nodes signify the possible moves or connections between different puzzle states. The graph captures the connectivity of the puzzle, allowing for multiple routes from the starting point "A" to the solution "S", leading us to the solution point using differents routes and paths

# %% [markdown]
# ### What are the advantages of using a visualisation such as the one shown?

# %% [markdown]
# - This type of graph offers several advantages, especially in the context of problem-solving, analysis, and communication. Visualizations provide an intuitive way to understand complex relationships and structures. And its edges represent connections or transitions, making it easier to grasp the overall problem and its possible solutions.
#
# - This visualizations allow you to explore different paths or routes in the problem space. By following edges and nodes, you can visually trace the steps from the starting point to the solution, helping to analyze possible strategies and outcomes.
#
# - It also help in identifying patterns and trends within the problem. For example, you can observe common subproblems, repeated stages, or specific routes that lead to the solution.
#
# - When there are multiple solutions or paths to reach the goal, visualizations make it easy to compare and contrast these solutions.
#
# - Visualizations provide support for decision-making. Whether you're deciding on the best route to take, analyzing the impact of a decision, or evaluating different strategies, a visual representation allows for a more informed decision-making process.

# %% [markdown]
# ### Demonstrate how Dijkstra’s algorithm would find the shortest path to the solution through diagrams and written explanation of each stage

# %% [markdown]
# A popular algorithm for finding the shortest paths in a graph is Dijkstra's algorithm. Essentially, it iteratively expands the set of known vertices and selects the vertex with the smallest tentative distance as the final vertex. Each edge has a weight, and our goal is to find the shortest path from node A to all other nodes and the solution point S. The numbers on the edges represent the weights.

# %% [markdown]
# ### Initialization

# %% [markdown]
# Set the initial node A distance to 0, and all other nodes distances to infinity.
#
# The distance from A to B is 1, the distance from A to C is 5, and the distance from A to H is 2, we will update the table to one of the unvisited nodes.
#
# So, B, C, and H are unvisited and its current distance is still infinity, so we can update the distance from A to B to 1 and store A as the previous node in the table and the same applies to the node C and H.
# We can update the shortest distance to C to the value of 5 and the shortest distance to H to the value of 2 and with the previous node of A. The first iteration ends here and we can mark A as visited, removing it from our unvisited nodes and adding it into the visited nodes.
#
# Visited nodes: [A]
#
# Unvisited nodes: [C, D, E, F, G, H, J, K, L, M, N, P, Q, R, S, T, U, V, W]
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Implementation 1

# %% [markdown]
# We choose a new node as current to explore its minimal distance in our unvisited nodes. So our table now is A with the value set to 0 as A is already visited . Our next unvisited node has a value set to its distance as 1, C has a distance of 5 and H a distance of 2, so for now all other nodes have distance to infinity, B has the shortest distance from our unvisited node so B is now our current node to iterate and calculate all unvisited neighbors.
# The unvisited neighbors of B are C and D and its how calculate its distance.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# B has a current distance of 1, we add this value to the weight of nodes C and D. Node C now has a current distance of 3 from A to B and we check if 3 is less than our current shortest distance stored in the table which is 5, so we set the sortest distance to 3 and our previous node to B and now we visited all unvisited neighbors of B.
#
# So the node D have the current distance of 5 from A to B, and now we need to check if 5 is less than our current shortest distance in the table which is infinity, so 5 is less than infinity, we update the shortest distance to 5 for the node D and set B as the previous node
#
# Visited nodes: [A, B]
#
# Unvisited nodes: [C, D, E, F, G, H, J, K, L, M, N, P, Q, R, S, T, U, V, W]
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Implementation 2

# %% [markdown]
# So now we do the same as before, we need to choose a new current node from  unvisited nodes with the shortest distance, which is H with the distance of 2. We calculate the distance to all unvisited neighbors of H and add 2 to the current distance because the shortest distance from A to H is 2.
#
# So now we do the same as before, we need to choose a new current node from  unvisited nodes with the shortest distance, which is H with the distance of 2. We calculate the distance to all unvisited neighbors of H and add 2 to the current distance because the shortest distance from A to H is 2.
#
#
# Visited nodes: [A, B, H]
#
# Unvisited nodes: [C, D, E, F, G, H, J, K, L, M, N, P, Q, R, S, T, U, V, W]
#
# ![image.png](attachment:image.png)
#
# - Also we need to check its neighbors which is J and K so we add the results into our table.The distance from A to J over H is 9 and from A to K over H is 7.
#
# ![image-5.png](attachment:image-5.png)
#
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# #### Implementation 3

# %% [markdown]
# Continue the iteration we choose a new current node from all unvisited nodes and with the shortest distance, which is C with the distance of 3. Now we calculate the all unvisited neighbors of C and add 3 because the shortest distance from A to C is 3 when look at the table we have so we need to update the distance to G which is the only neighbor of C. From A to G we have the value of 4, once our shortest distance in our table is set to infinity and 4 is less than infinity we update the shortest distance of G to 4 and set C as the previous node. so now C is finished we visited all the unvisited neighbors, so we mark C as visited.
#
# ![image.png](attachment:image.png)
#
# Visited nodes: [A, B, C, H]
#
# Unvisited nodes: [D, E, F, G, J, K, L, M, N, P, Q, R, S, T, U, V, W]
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Implementation 4

# %% [markdown]
# The next unvisited node list with the shortest distance is G as its value has a distance of 4. We calculate the distance from G to F, we need to get the current distance from A to G. Starting with the node F, if we calculate the distance from G to F we have the shortest distance with the distance of 5. Once our shortest distance is set to infinity and 6 is less than infinity, we update the shortest distance to F with the value of 6 and set G as the previous node. G is finished now as we visited all its neighbour, so we can add to the visited node.
#
# ![image.png](attachment:image.png)
#
# Visited nodes: [A, B, C, H, G]
#
# Unvisited nodes: [D, E, F, J, K, L, M, N, P, Q, R, S, T, U, V, W]
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Implementation 5

# %% [markdown]
# Next unvisited node with the current shortest distance is D with the distance of 5, firstly we calculate the distance from node D neigbours L and E. From A to D we have the current distance of 5, so calculating the distance from D to E we have the shortest distance of 9, and from D to L we have the distance of 12, our current shortest distance is 9 for both , so we don't update E on our table. However, the current shortest distance of L is set to infinity and 12 is less than infinity, so now we update the shortest distance of L to 12 and set D as the previous node. D is finished we visited all its neighbors we mark D as visited node.
#
# ![image-2.png](attachment:image-2.png)
#
# Visited nodes: [A, B, C, H, G, D]
#
# Unvisited nodes: [F, E, J, K, L, M, N, P, Q, R, S, T, U, V, W]
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Implementation 6

# %% [markdown]
# From the unvisited node list with the shortest distance, we have F with the distance of 6, we calculate the distance from its neighbors D and E.From A to F we have the distance of 6 which is the current distance.
# We calculate the distance from F to E and we find the shortest distance of 9 and the distance from F to D we find the shortest distance of 13. Our current shortest distance in the table is 5 for D, we dont need to update D and as the current shortest distance of E in the table is 9 and this is the current shortest we don't update the table. We are finished with F as we visited all its neighbors we mark F as visited node.
#
# Visited nodes: [A, B, C, H, G, D, F]
# Unvisited nodes: [E, J, K, L, M, N, P, Q, R, S, T, U, V, W]
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Implementation 7

# %% [markdown]
# From the unvisited nodes we have K with the current shortest distance of 7, so we calculate the distance from its neighbors H, J and L, from A to K we have the current shortest distance with a value of 7, so starting with node H if we calculate the distance from K to H we find the shortest distance of 12, and calculating the distanc from K to J we can find the shortest distance of 10 and the distance from K to L we have the shortest distance of 12, since the current shortest distance for H is 2 and it is shorter than 12 we wont update the table. For J we need to update the value in the table for 10 , our current shortest distance of J is 11 and 10 is shorter than 11 so J is updated to 10 and K as our previous node. As the current shortest distance of L in the table is 7 and 7 is less than 12, so we don't update the table. So now we are finished with K as we have already visited all unvisited neighbors of K and we mark K as visited node.
#
#
# ![image.png](attachment:image.png)
#
# Visited nodes: [A, B, C, H, G, F, D, K]
#
# Unvisited nodes: [E, J, L, M, N, P, Q, R, S, T, U, V, W]
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Implementation 8

# %% [markdown]
# In the next node from unvisited nodes with the shortest distance we have L as its distance is 7. The distance from node L to its neighbors K, N, M, V, W, D and G in this casse we need the result of 7 as the current distance from A to L is set to it, starging with node K we calculate the distance from L to K so we have the shortest distance of 12, and if we calculate the distance from L to N we obtain the shortest distance of 10, and the distance from L to M the shortest distance is 11 now we calculate the distance from L to V we have the shortest distance of 17 and the distance from L to W the shortest distance we found is 15, the distance from L to D the shortest distance of 14, and for the last we calculate the distance from L to G so we have the shortest distance of 10.
# The values of the current shortest distance of K,D and G are all less than 12,14 and 10 we dont need to update these nodes, as the current shortest distance of M,N,V and W are still infinity and 11,10,17 and 15 are shorter than infinity so our tabel will be updated as M with the value of 11, V with the value of 17, N the value of 10 and W the distance of 15 and we set L as previous node. Now L is finished as we visited all the unvisited neighbors and we can mark L as a visited node.
#
# So far we have the list of visited and unvisited nodes as follow:
#
# Visited nodes: [A, B, C, H, G, F, D, K, E, J, L]
#
# Unvisited nodes: [M, N, P, Q, R, S, T, U, V, W]
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Implementation 9

# %% [markdown]
# Next node from the list we have E with the shortest distance of 9, so the distance from node E to its neighbors D, F and W will be calculated as follow, the current distance we have 9 from A to E, so starting with node D if we calculate the distance from E to D we have the shortest distance of 13, and from E to F we find the shortest distance of 12 continuing as follow from E to W we have the shortest distance of 15. so our current shortest distance for D in the table is 5 and since 5 is shorter than 13 we dont need to update D in the table, and for F also as the current value in the table is 6 and it is less than 12. W being our current distance with the value of 15 we dont need to update the table for W. So node E is now finished with all the unvisited neighbors calculated. We mark E as visited node.
#
#
# Visited nodes: [A, B, C, H, G, F, D, K, E, L]
#
# Unvisited nodes: [J, M, N, P, Q, R, S, T, U, V, W]
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Implementation 10

# %% [markdown]
# ## Implementation of Dijkstra's algorithm

# %%
import heapq

def dijkstra_algorithm(graph, start, goal):
    
    # Set the distances with infinity for all nodes except the start node which is defined as 0
    distances = {node: float('infinity') for node in graph}
    distances[start] = 0

    # Priority queue to store (distance, node) pairs,then once stored it will populate the information
    priority_queue = [(0, start)]

    while priority_queue:
        current_distance, current_node = heapq.heappop(priority_queue)

        # Check if we reached the goal
        if current_node == goal:
            break

        # Update distances for neighboring nodes
        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                heapq.heappush(priority_queue, (distance, neighbor))

    # Return the shortest path and its distance
    return distances[goal]

#information given from the graph to generated dijkstra's algorithm to find the shortest path
example_graph = {
   'A': {'B': 1, 'C': 5, 'H': 2},
    'B': {'D': 4, 'C': 2, 'A': 1},
    'C': {'B': 2, 'G': 1},
    'D': {'B': 4, 'F': 7, 'L':7},
    'E': {'D': 4,'F': 3,'W': 6},
    'F': {'G': 2, 'D': 7, 'E': 3},
    'G': {'C': 1, 'F': 2, 'L': 3},
    'H': {'A': 2, 'K': 5, 'J': 9},
    'J': {'H': 9, 'N': 6, 'K': 3},
    'K': {'L': 5, 'H': 5, 'J': 3},
    'L': {'K': 5, 'N': 3, 'M': 4, 'V': 10, 'W': 8, 'G': 3, 'D': 7},
    'M': {'L': 4, 'P': 2, 'Q': 10},
    'N': {'J': 6, 'P': 4, 'L': 3, 'S': 7},
    'P': {'N': 4, 'R': 5, 'M': 2},
    'Q': {'M': 10, 'W': 4, 'S': 8},
    'R': {'S': 4, 'T': 3, 'P': 5},
    'S': {'R': 4, 'T': 4, 'U': 2, 'V':6, 'Q': 8, 'N': 7},
    'T': {'R': 3, 'S': 4, 'U': 1},
    'U': {'S': 2, 'T': 1, 'V': 3},
    'V': {'W': 5, 'S': 6, 'U': 3, 'L': 10},
    'W': {'E': 6, 'V': 5, 'Q': 4, 'L': 8},

}

start_node = 'A'
goal_node = 'S'

# Measure time for Dijkstra's algorithm
start_time_dijkstra = time.time()
dijkstra_solution = dijkstra_algorithm(example_graph, start_node, goal_node)
end_time_dijkstra = time.time()
time_taken_dijkstra = end_time_dijkstra - start_time_dijkstra

#Print the shortest distance from the start point set as A and reaching S
shortest_distance = dijkstra_algorithm(example_graph, start_node, goal_node)
print(f"Shortest distance from {start_node} to {goal_node}: {shortest_distance}")
print(f"Time taken for dijkstra algorithm: {time_taken_astar}")
# Out:
# Shortest distance from A to S: 17
# Time taken for dijkstra algorithm: 6.580352783203125e-05

# %% [markdown]
# # Implementation of A* search algorithm with heuristics

# %%
import heapq
import time

def astar_algorithm(graph, start, goal, heuristic_function):
    distances = {node: float('infinity') for node in graph}
    distances[start] = 0
    priority_queue = [(0, start)]

    while priority_queue:
        current_distance, current_node = heapq.heappop(priority_queue)

        if current_node == goal:
            break

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                priority = distance + heuristic_function(neighbor)
                heapq.heappush(priority_queue, (priority, neighbor))

    return distances[goal]

# Graph information and heuristic function
example_graph = {
    
    'A': {'B': 1, 'C': 5, 'H': 2},
    'B': {'A': 1, 'C': 2, 'D': 4},
    'C': {'A': 5, 'B': 2, 'G': 1},
    'D': {'B': 4, 'L': 7, 'F': 7, 'E': 4},
    'E': {'D': 4, 'F': 3, 'W': 6},
    'F': {'D': 7, 'E': 3, 'G': 2},
    'G': {'C': 1, 'F': 2, 'L': 3},
    'H': {'A': 2, 'J': 9, 'K': 5},
    'J': {'H': 9, 'K': 3, 'N': 6},
    'K': {'H': 5, 'J': 3, 'L': 5},
    'L': {'K': 5, 'N': 3, 'M': 4,'V': 10, 'W': 8, 'D': 7, 'G': 3},
    'N': {'L': 3, 'J': 6, 'P': 4, 'S': 7},
    'M': {'L': 4, 'P': 2, 'Q': 10},
    'P': {'N': 4, 'M': 2, 'R': 5},
    'Q': {'M': 10,'S': 8, 'W': 4},
    'R': {'P': 5, 'S': 4, 'T': 3},
    'S': {'Q': 8, 'N': 7, 'R': 4, 'T': 4, 'U': 2, 'V': 6},
    'T': {'R': 3, 'U': 1, 'S': 4},
    'U': {'T': 1, 'S': 2, 'V': 3},
    'V': {'U': 3, 'S': 6, 'L': 10, 'W': 5},
    'W': {'E': 6, 'L': 8, 'Q': 4, 'V': 5},
}

# Defining a heuristic function with node starting with 0
heuristic_function = lambda node: 0

start_node = 'A'
goal_node = 'S'

# Measure time for A* search algorithm
start_time_astar = time.time()
astar_solution = astar_algorithm(example_graph, start_node, goal_node, heuristic_function)
end_time_astar = time.time()
time_taken_astar = end_time_astar - start_time_astar

print(f"Shortest distance from {start_node} to {goal_node} using A*: {astar_solution}")
print(f"Time taken for A* algorithm: {time_taken_astar}")
# Out:
# Shortest distance from A to S using A*: 17
# Time taken for A* algorithm: 9.799003601074219e-05

# %% [markdown]
# # Algorithm Complexity

# %% [markdown]
# Time and space complexity of both algorithms.
#
# Dijkstra's Algorithm:
#
#     Time Complexity: O((V + E) * log(V))
#     Space Complexity: O(V + E)
#
# A* Algorithm:
#
#     Time Complexity: In the worst case, A* has the same time complexity as Dijkstra's algorithm.
#     Space Complexity: O(V)

# %% [markdown]
# # Comparison of Solutions:

# %% [markdown]
# Run both algorithms on your problem and compare the solutions generated.

# %% [markdown]
# - Dijkstra's algorithm
# dijkstra_solution = dijkstra_algorithm(graph, start, goal)
#
# - A* algorithm
# astar_solution = astar_algorithm(graph, start, goal, heuristic_function)

# %% [markdown]
# # Timing Analysis:

# %% [markdown]
# Comparing the actual time it takes for each algorithm to find the solution, using time module

# %%
import time
import heapq
import math

def dijkstra_algorithm(graph, start, goal):
    distances = {node: float('infinity') for node in graph}
    distances[start] = 0
    priority_queue = [(0, start)]

    while priority_queue:
        current_distance, current_node = heapq.heappop(priority_queue)

        if current_node == goal:
            break

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                heapq.heappush(priority_queue, (distance, neighbor))

    return distances[goal]

def astar_algorithm(graph, start, goal, heuristic_function):
    priority_queue = [(0, start)]
    g_values = {node: float('infinity') for node in graph}
    g_values[start] = 0

    while priority_queue:
        current_g, current_node = heapq.heappop(priority_queue)

        if current_node == goal:
            break

        for neighbor, weight in graph[current_node].items():
            tentative_g = g_values[current_node] + weight
            if tentative_g < g_values[neighbor]:
                g_values[neighbor] = tentative_g
                f_value = tentative_g + heuristic_function(neighbor, goal)
                heapq.heappush(priority_queue, (f_value, neighbor))

    return g_values[goal]

# Graph information
example_graph = {
    
    'A': {'B': 1, 'C': 5, 'H': 2},
    'B': {'D': 4, 'C': 2, 'A': 1},
    'C': {'B': 2, 'G': 1},
    'D': {'B': 4, 'F': 7, 'L':7},
    'E': {'D': 4,'F': 3,'W': 6},
    'F': {'G': 2, 'D': 7, 'E': 3},
    'G': {'C': 1, 'F': 2, 'L': 3},
    'H': {'A': 2, 'K': 5, 'J': 9},
    'J': {'H': 9, 'N': 6, 'K': 3},
    'K': {'L': 5, 'H': 5, 'J': 3},
    'L': {'K': 5, 'N': 3, 'M': 4, 'V': 10, 'W': 8, 'G': 3, 'D': 7},
    'M': {'L': 4, 'P': 2, 'Q': 10},
    'N': {'J': 6, 'P': 4, 'L': 3, 'S': 7},
    'P': {'N': 4, 'R': 5, 'M': 2},
    'Q': {'M': 10, 'W': 4, 'S': 8},
    'R': {'S': 4, 'T': 3, 'P': 5},
    'S': {'R': 4, 'T': 4, 'U': 2, 'V':6, 'Q': 8, 'N': 7},
    'T': {'R': 3, 'S': 4, 'U': 1},
    'U': {'S': 2, 'T': 1, 'V': 3},
    'V': {'W': 5, 'S': 6, 'U': 3, 'L': 10},
    'W': {'E': 6, 'V': 5, 'Q': 4, 'L': 8},
}

# Start and goal nodes, set A as starting point and S the destination we want to reach
start_node = 'A'
goal_node = 'S'

# Heuristic funciont to calculate our shortest path
def heuristic_function(node, goal):
    # Euclidean distance as a heuristic
    x1, y1 = node_coordinates[node]
    x2, y2 = node_coordinates[goal]
    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

# Coordinates of each node and its value
node_coordinates = {
    'A': (0, 0),
    'B': (1, 1),
    'C': (2, 0),
    'D': (3, 2),
    'E': (4, 1),
    'F': (5, 2),
    'G': (6, 0),
    'H': (1, 3),
    'J': (2, 4),
    'K': (3, 3),
    'L': (4, 4),
    'M': (5, 3),
    'N': (6, 4),
    'P': (7, 3),
    'Q': (8, 4),
    'R': (9, 3),
    'S': (5, 5),
    'T': (9, 4),
    'U': (8, 2),
    'V': (7, 5),
    'W': (6, 6),
}

# Measure time for Dijkstra's algorithm
start_time_dijkstra = time.time()
dijkstra_solution = dijkstra_algorithm(example_graph, start_node, goal_node)
end_time_dijkstra = time.time()
time_taken_dijkstra = end_time_dijkstra - start_time_dijkstra

# Measure time for A* algorithm
start_time_astar = time.time()
astar_solution = astar_algorithm(example_graph, start_node, goal_node, heuristic_function)
end_time_astar = time.time()
time_taken_astar = end_time_astar - start_time_astar

# Print the results
print(f"Shortest distance from {start_node} to {goal_node} using Dijkstra's: {dijkstra_solution}")
print(f"Time taken for Dijkstra's algorithm: {time_taken_dijkstra}")

print(f"Shortest distance from {start_node} to {goal_node} using A* Algorithm: {astar_solution}")
print(f"Time taken for A* algorithm: {time_taken_astar}")
# Out:
# Shortest distance from A to S using Dijkstra's: 17
# Time taken for Dijkstra's algorithm: 9.799003601074219e-05
# Shortest distance from A to S using A* Algorithm: 17
# Time taken for A* algorithm: 0.00011420249938964844

# %% [markdown]
# # 5. Comparison

# %% [markdown]
# ## Comparison of Dijkstra's Algorithm and A* Algorithm
#
# - **Efficiency:** Discuss the complexity of both algorithms and any observed differences.
# - **Solutions Generated:** Compare the solutions generated by each algorithm.
# - **Time Taken:** Compare the actual time it takes for each algorithm to find the solution.

# %% [markdown]
# ## References
#
# ‌www.javatpoint.com. (n.d.). Tree vs Graph data structure - javatpoint. [online] Available at: https://www.javatpoint.com/tree-vs-graph-data-structure.
#
# ‌GeeksforGeeks. (2019). Difference between graph and tree. [online] Available at: https://www.geeksforgeeks.org/difference-between-graph-and-tree/.
#
# ‌techgeekbuzz.com. (2019). Tree vs Graph: Notable Differences You Need to Know. [online] Available at: https://www.techgeekbuzz.com/blog/tree-vs-graph/ [Accessed 14 Nov. 2023].
#
# ‌Rachmawati, D. and Gustin, L. (2020). Analysis of Dijkstra’s Algorithm and A* Algorithm in Shortest Path Problem. Journal of Physics: Conference Series, 1566, p.012061. doi:https://doi.org/10.1088/1742-6596/1566/1/012061.
#
# ‌ocw.mit.edu. (n.d.). Introduction to Algorithms | Electrical Engineering and Computer Science | MIT OpenCourseWare. [online] Available at: https://ocw.mit.edu/courses/6-006-introduction-to-algorithms-spring-2020/.
#
# ‌Rachmawati, D. and Gustin, L. (2020). Analysis of Dijkstra’s Algorithm and A* Algorithm in Shortest Path Problem. Journal of Physics: Conference Series, 1566, p.012061. doi:https://doi.org/10.1088/1742-6596/1566/1/012061.
#
# ‌Cornell.edu. (2023). Available at: https://www.cs.cornell.edu/courses/cs2112/2021fa/lectures/ssp/ [Accessed 21 Nov. 2023].
#
# ‌geeksforgeeks (2023). What is Dijkstra’s Algorithm? | Introduction to Dijkstra’s Shortest Path Algorithm. [online] GeeksforGeeks. Available at: https://www.geeksforgeeks.org/introduction-to-dijkstras-shortest-path-algorithm/.
#
# ‌Stack Abuse. (n.d.). Graphs in Python - Theory and Implementation. [online] Available at: https://stackabuse.com/courses/graphs-in-python-theory-and-implementation/lessons/dijkstras-algorithm-vs-a-algorithm/.
#
# ‌
